# %%
from  selenium import webdriver 
from bs4 import BeautifulSoup as bs
import re 
from translate import Translator
import string
import re
from time import  sleep
from selenium.common.exceptions import TimeoutException
import pickle
from collections import deque
from selenium.webdriver.common.by import By
import pandas as pd

# %%
with open("state.pkl",'rb') as file:
        all_data,stack,link=pickle.load(file)
len(all_data)
# Out:
# 4384

# %%
df=pd.DataFrame(all_data)

# %%
with open("state.pkl",'rb') as file:
        all_data2,stack2,link2=pickle.load(file)
len(all_data2)
# Out:
# 4384

# %%
df=pd.DataFrame(all_data)

# %%
df
# Out:
#                price                       location               data  \
# 0          5,999 EGP             Sheikh Zayed، Giza       2 March 2022
# 1      1,619,500 EGP               Ain Sukhna، Suez   26 February 2022
# 2     11,500,000 EGP  New Cairo - El Tagamoa، Cairo   27 February 2022
# 3      1,800,000 EGP              Rehab City، Cairo       2 March 2022
# 4      5,000,000 EGP        New Capital City، Cairo       3 March 2022
# ...              ...                            ...                ...
# 4379     500,000 EGP               Badr City، Cairo       8 March 2022
# 4380       4,000 EGP            Nakheel، Alexandria       8 March 2022
# 4381     490,000 EGP            Shorouk City، Cairo       8 March 2022
# 4382   2,800,000 EGP             Sheikh Zayed، Giza       8 March 2022
# 4383       3,000 EGP              Asyut City، Asyut       8 March 2022
#
#                                                   title  \
# 0                         مكتب مساحة ٣١ متر بالشيخ زايد
# 1                Penthouse for sale in blumar El-Sokhna
# 2     Good opportunity & HOT PRICE _ Villa 705 m in ...
# 3     لقطططة ... للبيع بالرحاب شقة 119م بالمرحلة الع...
# 4     لأول مرة بالعاصمة محل تجارى بعائد 495 الف وإيج...
# ...                                                 ...
# 4379                      شقة ببدر المصرية متشطبة للبيع
# 4380         شقة مفروشة للايجار بشاطئ النخيل الاسكندريه
# 4381  محل للبيع فى الشروق 16م على واجهة المول استلام...
# 4382  Penthouse for sale in zayed dunes 242 sqm semi...
# 4383                               شقة دور ارضي للايجار
#
#                                                    link Area (m²) Furnished  \
# 0            https://www.olx.com.eg/en/ad/-IDcyvl0.html      [31]      [No]
# 1     https://www.olx.com.eg/en/ad/penthouse-for-sal...     [110]     [Yes]
# 2     https://www.olx.com.eg/en/ad/good-opportunity-...     [705]      [No]
# 3         https://www.olx.com.eg/en/ad/119-IDcGqvm.html     [119]      [No]
# 4      https://www.olx.com.eg/en/ad/495-20-IDcGAWm.html      [42]       NaN
# ...                                                 ...       ...       ...
# 4379         https://www.olx.com.eg/en/ad/-IDcHee0.html     [110]      [No]
# 4380         https://www.olx.com.eg/en/ad/-IDcHedG.html     [120]     [Yes]
# 4381       https://www.olx.com.eg/en/ad/16-IDcHee3.html      [16]       NaN
# 4382  https://www.olx.com.eg/en/ad/penthouse-for-sal...     [242]      [No]
# 4383         https://www.olx.com.eg/en/ad/-IDcHedr.html      [70]     [Yes]
#
#                               Type  \
# 0     [Full, Commercial, Building]
# 1                      [Penthouse]
# 2            [Stand, Alone, Villa]
# 3                      [Apartment]
# 4                         [Retail]
# ...                            ...
# 4379                   [Apartment]
# 4380                   [Apartment]
# 4381                      [Retail]
# 4382                   [Penthouse]
# 4383                   [Apartment]
#
#                                               Amenities Bedrooms Bathrooms  \
# 0                                                   NaN      NaN       NaN
# 1     [Balcony, Central, A/C, &, heating, Security, ...      [2]       [1]
# 2     [Balcony, Private, Garden, Security, Covered, ...      [6]       [6]
# 3                                                   NaN      [3]       [3]
# 4                          [Covered, Parking, Security]      NaN       NaN
# ...                                                 ...      ...       ...
# 4379  [Security, Electricity, Meter, Water, Meter, N...      [3]       [2]
# 4380                                                 []      [3]       [1]
# 4381                                                NaN      NaN       NaN
# 4382  [Balcony, Security, Covered, Parking, Maids, R...      [4]       [4]
# 4383  [Built, in, Kitchen, Appliances, Electricity, ...      [2]       [1]
#
#          Level           Payment Option          Compound      Delivery Date  \
# 0          NaN                      NaN               NaN                NaN
# 1          [2]                   [Cash]  [Blumar, Sokhna]  [Ready, to, move]
# 2          NaN                   [Cash]       [Les, Rois]  [Ready, to, move]
# 3          [1]                   [Cash]               NaN  [Ready, to, move]
# 4          NaN            [Installment]               NaN                NaN
# ...        ...                      ...               ...                ...
# 4379       [1]                      NaN               NaN                NaN
# 4380       [1]                      NaN               NaN                NaN
# 4381       NaN  [Cash, or, Installment]               NaN  [Ready, to, move]
# 4382       [3]                   [Cash]    [Zayed, Dunes]  [Ready, to, move]
# 4383  [Ground]                      NaN               NaN                NaN
#
#          Delivery Term Down Payment Sale/Rent vlaues
# 0                  NaN          NaN       NaN    NaN
# 1           [Finished]          NaN       NaN    NaN
# 2     [Core, &, Shell]          NaN       NaN    NaN
# 3                  NaN          NaN       NaN    NaN
# 4                  NaN          NaN       NaN    NaN
# ...                ...          ...       ...    ...
# 4379               NaN          NaN       NaN    NaN
# 4380               NaN          NaN       NaN    NaN
# 4381               NaN          NaN       NaN    NaN
# 4382   [Not, Finished]          NaN       NaN    NaN
# 4383               NaN          NaN       NaN    NaN
#
# [4384 rows x 19 columns]
