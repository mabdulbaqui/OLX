# %%
import sqlite3

# %%
connection = sqlite3.connect("data__db.db")
rows = connection.execute("SELECT * FROM users").fetchall()
connection.close()
rows
# Out:
# [(0,
#   7000.0,
#   'Rehab City، Cairo',
#   ' 16 March 2022',
#   182,
#   0,
#   2.0,
#   1.0,
#   99.0,
#   'Yes',
#   3,
#   'Apartment',
#   'Rehab City',
#   None,
#   None,
#   'Rent',
#   None,
#   None,
#   None),
#  (1,
#   12000.0,
#   'Rehab City، Cairo',
#   ' 10 February 2022',
#   266,
#   0,
#   3.0,
#   3.0,
#   155.0,
#   'Yes',
#   1,
#   'Apartment',
#   'Rehab City',
#   'Balcony Built in Kitchen Appliances Central A/C & heating Security Electricity Meter Natural Gas Landline',
#   48000.0,
#   'Rent',
#   None,
#   None,
#   None),
#  (2,
#   6000.0,
#   'Madinaty، Cairo',
#   ' 10 March 2022',
#   658,
#   0,
#   3.0,
#   2.0,
#   140.0,
#   None,
#   3,
#   'Apartment',
#   'Madinaty',
#   'Balcony Security Pets Allowed Electricity Meter Water Meter Elevator',
#   None,
#   'Rent',
#   None,
#   None,
#   None),
#  (3,
#   17000.0,
#   'Sheikh Zayed، Giza',
#   ' 28 February 2022',
#   730,
#   0,
#   3.0,
#   3.0,
#   280.0,
#   'No',
#   0,
#   'Duplex',
# ...

# %% [markdown]
# git properties for Rent

# %%
connection = sqlite3.connect("data__db.db")
rows = connection.execute("SELECT * FROM users WHERE cat ='Rent'").fetchall()
connection.close()
rows
# Out:
# [(0,
#   7000.0,
#   'Rehab City، Cairo',
#   ' 16 March 2022',
#   182,
#   0,
#   2.0,
#   1.0,
#   99.0,
#   'Yes',
#   3,
#   'Apartment',
#   'Rehab City',
#   None,
#   None,
#   'Rent',
#   None,
#   None,
#   None),
#  (1,
#   12000.0,
#   'Rehab City، Cairo',
#   ' 10 February 2022',
#   266,
#   0,
#   3.0,
#   3.0,
#   155.0,
#   'Yes',
#   1,
#   'Apartment',
#   'Rehab City',
#   'Balcony Built in Kitchen Appliances Central A/C & heating Security Electricity Meter Natural Gas Landline',
#   48000.0,
#   'Rent',
#   None,
#   None,
#   None),
#  (2,
#   6000.0,
#   'Madinaty، Cairo',
#   ' 10 March 2022',
#   658,
#   0,
#   3.0,
#   2.0,
#   140.0,
#   None,
#   3,
#   'Apartment',
#   'Madinaty',
#   'Balcony Security Pets Allowed Electricity Meter Water Meter Elevator',
#   None,
#   'Rent',
#   None,
#   None,
#   None),
#  (3,
#   17000.0,
#   'Sheikh Zayed، Giza',
#   ' 28 February 2022',
#   730,
#   0,
#   3.0,
#   3.0,
#   280.0,
#   'No',
#   0,
#   'Duplex',
# ...

# %% [markdown]
# git properties for sell

# %%
connection = sqlite3.connect("data__db.db")
rows = connection.execute("SELECT * FROM users WHERE cat ='Sell'").fetchall()
connection.close()
rows
# Out:
# [(21735,
#   2560000.0,
#   'Smoha، Alexandria',
#   ' 1 January 2022',
#   67,
#   0,
#   3.0,
#   2.0,
#   160.0,
#   None,
#   7,
#   'Apartment',
#   None,
#   None,
#   None,
#   'Sell',
#   'Installment',
#   None,
#   None),
#  (21736,
#   1650000.0,
#   'Nasr City، Cairo',
#   ' 10 March 2022',
#   629,
#   0,
#   3.0,
#   2.0,
#   160.0,
#   'No',
#   1,
#   'Apartment',
#   None,
#   'Balcony Built in Kitchen Appliances Private Garden Security Covered Parking Pets Allowed Electricity Meter Water Meter Natural Gas Landline Elevator',
#   None,
#   'Sell',
#   'Cash',
#   'Ready to move',
#   None),
#  (21737,
#   2380000.0,
#   'New Capital City, Cairo',
#   ' 13 February 2022',
#   28,
#   1,
#   2.0,
#   2.0,
#   119.0,
#   None,
#   0,
#   'Apartment',
#   'Atika',
#   'Balcony Covered Parking Maids Room Pets Allowed Private Garden Security Pool Electricity Meter Water Meter Natural Gas Landline Elevator',
#   None,
#   'Sell',
#   'Cash or Installment',
# ...

# %% [markdown]
# git villas for sell

# %%
connection = sqlite3.connect("data__db.db")
rows = connection.execute("SELECT * FROM users WHERE cat ='Sell' AND Type  IN ('Stand Alone Villa' ,'Town House' ,'Twin House')").fetchall()
connection.close()
rows
# Out:
# [(47194,
#   7400000.0,
#   'Sheikh Zayed، Giza',
#   ' 9 March 2022',
#   54,
#   0,
#   4.0,
#   4.0,
#   338.0,
#   None,
#   None,
#   'Stand Alone Villa',
#   'Lake West',
#   None,
#   None,
#   'Sell',
#   'Cash or Installment',
#   None,
#   'Core & Shell'),
#  (47195,
#   7700000.0,
#   'Rehab City، Cairo',
#   ' 1 March 2022',
#   291,
#   0,
#   3.0,
#   3.0,
#   456.0,
#   'No',
#   None,
#   'Stand Alone Villa',
#   None,
#   'Balcony Pets Allowed Private Garden Security Electricity Meter Water Meter Natural Gas Landline',
#   None,
#   'Sell',
#   'Cash',
#   'Ready to move',
#   'Finished'),
#  (47196,
#   4900000.0,
#   'Shorouk City، Cairo',
#   ' 10 January 2022',
#   205,
#   0,
#   4.0,
#   2.0,
#   245.0,
#   'No',
#   None,
#   'Town House',
#   'GCR',
#   'Balcony Built in Kitchen Appliances Maids Room Pets Allowed Private Garden Security Pool Electricity Meter Water Meter Natural Gas Landline',
#   None,
#   'Sell',
#   'Cash or Installment',
#   '2022',
# ...

# %% [markdown]
# git villas for Rent

# %%
connection = sqlite3.connect("data__db.db")
rows = connection.execute("SELECT * FROM users WHERE cat ='Rent' AND Type  IN ('Stand Alone Villa' ,'Town House' ,'Twin House')").fetchall()
connection.close()
rows
# Out:
# [(42052,
#   37000.0,
#   'New Cairo - El Tagamoa, Cairo',
#   ' 2 March 2022',
#   181,
#   0,
#   3.0,
#   3.0,
#   300.0,
#   'No',
#   None,
#   'Twin House',
#   'Mivida',
#   'Balcony Central A/C & heating Covered Parking Maids Room Private Garden Security Electricity Meter',
#   None,
#   'Rent',
#   None,
#   None,
#   None),
#  (42053,
#   21000.0,
#   'Madinaty، Cairo',
#   ' 9 March 2022',
#   296,
#   0,
#   3.0,
#   3.0,
#   222.0,
#   None,
#   None,
#   'Town House',
#   None,
#   None,
#   None,
#   'Rent',
#   None,
#   None,
#   None),
#  (42054,
#   18000.0,
#   'Rehab City، Cairo',
#   ' 17 February 2022',
#   182,
#   1,
#   4.0,
#   4.0,
#   300.0,
#   'No',
#   None,
#   'Town House',
#   'Rehab City',
#   'Balcony Private Garden Security Covered Parking Maids Room Electricity Meter Water Meter Natural Gas Landline',
#   6.0,
#   'Rent',
#   None,
#   None,
#   None),
#  (42055,
#   38000.0,
#   'Sheikh Zayed، Giza',
#   ' 10 March 2022',
#   116,
#   0,
# ...

# %% [markdown]
# how many villas for Sell

# %%
connection = sqlite3.connect("data__db.db")
rows = connection.execute("SELECT count(*) FROM users WHERE cat ='Sell' AND Type  IN ('Stand Alone Villa' ,'Town House' ,'Twin House')").fetchall()
connection.close()
rows
# Out:
# [(21703,)]

# %%
connection = sqlite3.connect("data__db.db")
rows = connection.execute("SELECT count(*) FROM users WHERE cat ='Rent' AND Type  IN ('Stand Alone Villa' ,'Town House' ,'Twin House')").fetchall()
connection.close()
rows
# Out:
# [(5104,)]

# %% [markdown]
# avrage price for villas for Rent

# %%
connection = sqlite3.connect("data__db.db")
rows = connection.execute("SELECT AVG(price) FROM users WHERE cat ='Rent' AND Type  IN ('Stand Alone Villa' ,'Town House' ,'Twin House')").fetchall()
connection.close()
rows
# Out:
# [(35879.145572100315,)]

# %% [markdown]
# Avrage price for villas for Sell

# %%
connection = sqlite3.connect("data__db.db")
rows = connection.execute("SELECT AVG(price) FROM users WHERE cat ='Sell' AND Type  IN ('Stand Alone Villa' ,'Town House' ,'Twin House')").fetchall()
connection.close()
rows
# Out:
# [(8580518.738054646,)]

# %% [markdown]
# Avrage  price for each compuned

# %%
connection = sqlite3.connect("data__db.db")
rows = connection.execute("SELECT AVG(price) FROM users  GROUP BY Compound ORDER BY price DESC").fetchall()
connection.close()
rows
# Out:
# [(90000000.0,),
#  (21860869.56521739,),
#  (20825000.0,),
#  (8130000.0,),
#  (12125000.0,),
#  (6231707.142857143,),
#  (9021666.666666666,),
#  (17789871.0,),
#  (12000000.0,),
#  (11208875.0,),
#  (7867363.5,),
#  (11331960.0,),
#  (8625000.0,),
#  (7587945.833333333,),
#  (15500000.0,),
#  (8000000.0,),
#  (11000000.0,),
#  (8391471.255060729,),
#  (7500000.0,),
#  (7471668.090909091,),
#  (8810614.775510205,),
#  (6430164.885714286,),
#  (7417750.0,),
#  (7000000.0,),
#  (9480000.0,),
#  (5487500.0,),
#  (6750000.0,),
#  (3697142.8571428573,),
#  (5171185.855614973,),
#  (6485000.0,),
#  (6203026.178947369,),
#  (6150000.0,),
#  (4669583.333333333,),
#  (8104077.8,),
#  (5466666.666666667,),
#  (4529166.583333333,),
#  (5860487.804878049,),
#  (5200000.0,),
#  (6425222.080291971,),
#  (4282829.642857143,),
#  (6600000.0,),
#  (6447868.25,),
#  (4450000.0,),
#  (4751666.666666667,),
#  (6386666.666666667,),
#  (16378307.692307692,),
#  (4147702.2558139535,),
# ...

# %% [markdown]
# Avrage  price for each Location

# %%
connection = sqlite3.connect("data__db.db")
rows = connection.execute("SELECT AVG(price) FROM users  GROUP BY Location ORDER BY price DESC").fetchall()
connection.close()
rows
# Out:
# [(65000000.0,),
#  (15000000.0,),
#  (8500000.0,),
#  (6000000.0,),
#  (6500000.0,),
#  (5555666.0,),
#  (5200000.0,),
#  (2502500.0,),
#  (4406666.666666667,),
#  (5000000.0,),
#  (3000000.0,),
#  (4764000.0,),
#  (4514546.935622318,),
#  (2000000.0,),
#  (1001000.0,),
#  (2501133.1428571427,),
#  (1400000.0,),
#  (1600000.0,),
#  (1500000.0,),
#  (1500000.0,),
#  (1400000.0,),
#  (675000.0,),
#  (1300000.0,),
#  (4366666.666666667,),
#  (1250000.0,),
#  (1050000.0,),
#  (1200000.0,),
#  (697500.0,),
#  (850000.0,),
#  (975000.0,),
#  (900000.0,),
#  (1425000.0,),
#  (850000.0,),
#  (570000.0,),
#  (5375000.0,),
#  (704779.4285714285,),
#  (239140.0,),
#  (700000.0,),
#  (700000.0,),
#  (580000.0,),
#  (560000.0,),
#  (550000.0,),
#  (520000.0,),
#  (502000.0,),
#  (1850000.0,),
#  (480000.0,),
#  (450000.0,),
#  (692000.0,),
#  (2546500.0,),
#  (424000.0,),
#  (335833.3333333333,),
#  (387500.0,),
#  (330000.0,),
#  (380000.0,),
#  (370000.0,),
#  (360000.0,),
#  (600000.0,),
# ...

# %% [markdown]
# what is the most Delivery Term

# %%
connection = sqlite3.connect("data__db.db")
rows = connection.execute("SELECT COUNT(price) FROM users  GROUP BY [Delivery Term] ORDER BY price ASC").fetchall()
connection.close()
rows[0][0]
# Out:
# 46369

# %% [markdown]
# what is the most Payment Option

# %%
connection = sqlite3.connect("data__db.db")
rows = connection.execute("SELECT COUNT(price) FROM users  GROUP BY [Payment Option] ORDER BY price ASC").fetchall()
connection.close()
rows[0][0]
# Out:
# 34850

# %%
connection = sqlite3.connect("data__db.db")
rows = connection.execute("SELECT COUNT(price) FROM users  GROUP BY [Delivery Date] ORDER BY price ASC").fetchall()
connection.close()
rows[0][0]
# Out:
# 41213
