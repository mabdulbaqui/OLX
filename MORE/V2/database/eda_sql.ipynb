# %%
import sqlite3

# %%
connection = sqlite3.connect("data__db.db")
rows = connection.execute("SELECT * FROM users").fetchall()
connection.close()
rows
# Out:
# [(0,
#   7000.0,
#   'Rehab City، Cairo',
#   ' 16 March 2022',
#   182,
#   0,
#   2.0,
#   1.0,
#   99.0,
#   'Yes',
#   3,
#   'Apartment',
#   'Rehab City',
#   None,
#   None,
#   'Rent',
#   None,
#   None,
#   None),
#  (1,
#   12000.0,
#   'Rehab City، Cairo',
#   ' 10 February 2022',
#   266,
#   0,
#   3.0,
#   3.0,
#   155.0,
#   'Yes',
#   1,
#   'Apartment',
#   'Rehab City',
#   'Balcony Built in Kitchen Appliances Central A/C & heating Security Electricity Meter Natural Gas Landline',
#   48000.0,
#   'Rent',
#   None,
#   None,
#   None),
#  (2,
#   6000.0,
#   'Madinaty، Cairo',
#   ' 10 March 2022',
#   658,
#   0,
#   3.0,
#   2.0,
#   140.0,
#   None,
#   3,
#   'Apartment',
#   'Madinaty',
#   'Balcony Security Pets Allowed Electricity Meter Water Meter Elevator',
#   None,
#   'Rent',
#   None,
#   None,
#   None),
#  (3,
#   17000.0,
#   'Sheikh Zayed، Giza',
#   ' 28 February 2022',
#   730,
#   0,
#   3.0,
#   3.0,
#   280.0,
#   'No',
#   0,
#   'Duplex',
# ...

# %%
connection = sqlite3.connect("data__db.db")
rows = connection.execute("SELECT * FROM users while cat=='re'").fetchall()
connection.close()
rows
